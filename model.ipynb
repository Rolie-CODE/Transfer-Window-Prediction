# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('data/data.csv', sep=';', encoding='latin1')

# %%
print(data.head())
print(data.shape)
# Out:
#    Rk             Player Nation   Pos         Squad            Comp  Age  \
# 0   1   Brenden Aaronson    USA  MFFW  Leeds United  Premier League   22
# 1   2   Yunis Abdelhamid    MAR    DF         Reims         Ligue 1   35
# 2   3      Himad Abdelli    FRA  MFFW        Angers         Ligue 1   23
# 3   4  Salis Abdul Samed    GHA    MF          Lens         Ligue 1   22
# 4   5    Laurent Abergel    FRA    MF       Lorient         Ligue 1   30
#
#    Born  MP  Starts  ...   Off   Crs  TklW  PKwon  PKcon    OG  Recov  AerWon  \
# 0  2000  20      19  ...  0.17  2.54  0.51    0.0    0.0  0.00   4.86    0.34
# 1  1987  22      22  ...  0.05  0.18  1.59    0.0    0.0  0.00   6.64    2.18
# 2  1999  14       8  ...  0.00  1.05  1.40    0.0    0.0  0.00   8.14    0.93
# 3  2000  20      20  ...  0.00  0.35  0.80    0.0    0.0  0.05   6.60    0.50
# 4  1993  15      15  ...  0.00  0.23  2.02    0.0    0.0  0.00   6.51    0.31
#
#    AerLost  AerWon%
# 0     1.19     22.2
# 1     1.23     64.0
# 2     1.05     47.1
# 3     0.50     50.0
# 4     0.39     44.4
#
# [5 rows x 124 columns]
# (2689, 124)

# %%
print(data.columns)
# Out:
# Index(['Rk', 'Player', 'Nation', 'Pos', 'Squad', 'Comp', 'Age', 'Born', 'MP',
#        'Starts',
#        ...
#        'Off', 'Crs', 'TklW', 'PKwon', 'PKcon', 'OG', 'Recov', 'AerWon',
#        'AerLost', 'AerWon%'],
#       dtype='object', length=124)

# %%
pv = pd.read_csv('data/player_valuations.csv')

# %%
print(pv.head())
# Out:
#    player_id        date  market_value_in_eur current_club_name  \
# 0     405973  2000-01-20               150000           Unknown
# 1     342216  2001-07-20               100000           Unknown
# 2       3132  2003-12-09               400000       Dynamo Kyiv
# 3       6893  2003-12-15               900000       Galatasaray
# 4         10  2004-10-04              7000000  SV Werder Bremen
#
#    current_club_id player_club_domestic_competition_id
# 0             3057                                 BE1
# 1             1241                                 SC1
# 2              126                                 TR1
# 3              984                                 GB1
# 4              398                                 IT1

# %%
data1 = pd.read_csv('data/data1.csv')

# %%
print(data1.head())
# Out:
#    appearance_id  game_id  player_id  player_club_id  player_current_club_id  \
# 0  2231978_38004  2231978      38004             853                     235
# 1   2235545_4520  2235545       4520             317                     317
# 2   2235545_4582  2235545       4582             317                     317
# 3  2235545_19409  2235545      19409             317                     200
# 4  2235539_28716  2235539      28716             282                    7185
#
#          date       player_name competition_id  yellow_cards  red_cards  \
# 0  2012-07-03  Aurélien Joachim            CLQ             0          0
# 1  2012-07-05   Peter Wisgerhof            ELQ             0          0
# 2  2012-07-05   Sander Boschker            ELQ             0          0
# 3  2012-07-05    Willem Janssen            ELQ             0          0
# 4  2012-07-05      Adi Adilovic            ELQ             0          0
#
#    goals  assists  minutes_played market_value_date  market_value_in_eur
# 0      2        0              90        2010-01-04             175000.0
# 1      0        0              90        2011-06-15            3000000.0
# 2      0        0              90        2012-01-05             250000.0
# 3      0        0              45        2012-01-05            2500000.0
# 4      0        0              90        2012-03-11             450000.0

# %%
data1.isnull().sum()
# Out:
# appearance_id             0
# game_id                   0
# player_id                 0
# player_club_id            0
# player_current_club_id    0
# date                      0
# player_name               0
# competition_id            0
# yellow_cards              0
# red_cards                 0
# goals                     0
# assists                   0
# minutes_played            0
# market_value_date         0
# market_value_in_eur       0
# dtype: int64

# %%
target = data1['market_value_in_eur']
new_set = data1.drop(['market_value_in_eur', 'market_value_date'], axis = 1)

# %%
print(target)
print(new_set)
# Out:
# 0            175000.0
# 1           3000000.0
# 2            250000.0
# 3           2500000.0
# 4            450000.0
#               ...
# 1875900    80000000.0
# 1875901      600000.0
# 1875902    15000000.0
# 1875903      325000.0
# 1875904      350000.0
# Name: market_value_in_eur, Length: 1875905, dtype: float64
#            appearance_id  game_id  player_id  player_club_id  \
# 0          2231978_38004  2231978      38004             853
# 1           2235545_4520  2235545       4520             317
# 2           2235545_4582  2235545       4582             317
# 3          2235545_19409  2235545      19409             317
# 4          2235539_28716  2235539      28716             282
# ...                  ...      ...        ...             ...
# 1875900   4776665_948294  4776665     948294            3437
# 1875901   4776668_989069  4776668     989069            3563
# 1875902  4776668_1016015  4776668    1016015            3854
# 1875903  4776665_1059056  4776665    1059056           15737
# 1875904  4776665_1252820  4776665    1252820           15737
#
#          player_current_club_id        date       player_name competition_id  \
# 0                           235  2012-07-03  Aurélien Joachim            CLQ
# 1                           317  2012-07-05   Peter Wisgerhof            ELQ
# 2                           317  2012-07-05   Sander Boschker            ELQ
# 3                           200  2012-07-05    Willem Janssen            ELQ
# 4                          7185  2012-07-05      Adi Adilovic            ELQ
# ...                         ...         ...               ...            ...
# 1875900                    1047  2026-06-28          Nico Paz           FIWC
# 1875901                   15300  2026-06-28  Jakhongir Urozov           FIWC
# 1875902                    1082  2026-06-28   Ngal'ayel Mukau           FIWC
# 1875903                    9840  2026-06-28       Ali Azaizeh           FIWC
# 1875904                   44664  2026-06-28     Odeh Fakhoury           FIWC
#
#          yellow_cards  red_cards  goals  assists  minutes_played
# 0                   0          0      2        0              90
# 1                   0          0      0        0              90
# 2                   0          0      0        0              90
# 3                   0          0      0        0              45
# 4                   0          0      0        0              90
# ...               ...        ...    ...      ...             ...
# 1875900             0          0      0        0              61
# 1875901             0          0      0        0              82
# 1875902             0          0      0        0              18
# 1875903             0          0      0        0              45
# 1875904             0          0      0        0              45
#
# [1875905 rows x 13 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(new_set, target, test_size=0.1, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19912\1905445833.py in ?()
#       1 model = LinearRegression()
# ----> 2 model.fit(X_train, y_train)
#
# c:\Users\asm\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1361                 skip_parameter_validation=(
#    1362                     prefer_skip_nested_validation or global_skip_validation
#    1363                 )
#    1364             ):
# -> 1365                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\asm\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
#     614         n_jobs_ = self.n_jobs
#     615
#     616         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     617
# --> 618         X, y = validate_data(
#     619             self,
#     620             X,
#     621             y,
#
# c:\Users\asm\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2967             if "estimator" not in check_y_params:
#    2968                 check_y_params = {**default_check_params, **check_y_params}
#    2969             y = check_array(y, input_name="y", **check_y_params)
#    2970         else:
# -> 2971             X, y = check_X_y(X, y, **check_params)
#    2972         out = X, y
#    2973
#    2974     if not no_val_X and check_params.get("ensure_2d", True):
#
# c:\Users\asm\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1364         )
#    1365
#    1366     ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
#    1367
# -> 1368     X = check_array(
#    1369         X,
#    1370         accept_sparse=accept_sparse,
#    1371         accept_large_sparse=accept_large_sparse,
#
# c:\Users\asm\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1050                         )
#    1051                     array = xp.astype(array, dtype, copy=False)
#    1052                 else:
#    1053                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1054             except ComplexWarning as complex_warning:
#    1055                 raise ValueError(
#    1056                     "Complex data not supported\n{}\n".format(array)
#    1057                 ) from complex_warning
#
# c:\Users\asm\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     753         # Use NumPy API to support order
#     754         if copy is True:
#     755             array = numpy.array(array, order=order, dtype=dtype)
#     756         else:
# --> 757             array = numpy.asarray(array, order=order, dtype=dtype)
#     758
#     759         # At this point array is a NumPy ndarray. We convert it to an array
#     760         # container that is consistent with the input's namespace.
#
# c:\Users\asm\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2167             )
#    2168         values = self._values
#    2169         if copy is None:
#    2170             # Note: branch avoids `copy=None` for NumPy 1.x support
# -> 2171             arr = np.asarray(values, dtype=dtype)
#    2172         else:
#    2173             arr = np.array(values, dtype=dtype, copy=copy)
#    2174
#
# ValueError: could not convert string to float: '2017-10-15'
